# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# drive  sample_data

# %%
#!unzip /content/drive/MyDrive/Hack_Sochi/train_dataset_train.zip -d /content/drive/MyDrive/Hack_Sochi/

# %%
# !unzip /content/drive/MyDrive/Hack_Sochi/test_dataset_test.zip -d /content/drive/MyDrive/Hack_Sochi/
# Out:
# Archive:  /content/drive/MyDrive/Hack_Sochi/test_dataset_test.zip
#    creating: /content/drive/MyDrive/Hack_Sochi/test/
#   inflating: /content/drive/MyDrive/Hack_Sochi/test/test.csv
#   inflating: /content/drive/MyDrive/Hack_Sochi/__MACOSX/test/._test.csv
#   inflating: /content/drive/MyDrive/Hack_Sochi/test/sample_submission.csv
#   inflating: /content/drive/MyDrive/Hack_Sochi/__MACOSX/test/._sample_submission.csv

# %%
# !ls /content/drive/MyDrive/Hack_Sochi/test
# Out:
# sample_submission.csv  test.csv

# %% [markdown]
# ### Файл cntrbtrs.csv - счета и типы пенсионных схем

# %%
import pandas as pd
import numpy as np

# %%
 test = pd.read_csv('/content/drive/MyDrive/Hack_Sochi/test/test.csv')

# %%
test.head()
# Out:
#    slctn_nmbr                           client_id  \
# 0           0  0x589BC912CB844D468212ADD42EAE4151
# 1           2  0xCCF22420C90AE4459A25781A9A30F445
# 2           3  0x943D2C768A4FB38311E6605EEA2B9E4A
# 3           2  0x99E64FD29CC3B04189C5C9EBEAF6F9A4
# 4           0  0x654EEEBA731C4A4881816631229C5B65
#
#                        npo_account_id  npo_accnts_nmbr  pmnts_type  year  \
# 0  0xAA9E8DDF1310724995598EA2B42D7D87                2           1  2017
# 1  0x3B9B09857D152F468A42C5DEE6D723F7                1           3  2021
# 2  0xA7F12C768A4FB38311E835E4A7632E00                1           2  2015
# 3  0xBFE4BDFBE0E037478C29BA4F38121B15                1           1  2015
# 4  0x4B5C7804E403C842B4ECBF69BC3EDD7C                2           1  2011
#
#   quarter  gender  age  clnt_cprtn_time_d  actv_prd_d  lst_pmnt_rcnc_d  \
# 0  2017Q2       1   54               6595        4543               31
# 1  2021Q4       1   75               7078           0             2209
# ...

# %%
test['year'].value_counts().sort_index()
# Out:
# year
# 1993      498
# 1994     1672
# 1995      340
# 1996     1771
# 1997     2669
# 1998     2079
# 1999     6396
# 2000     7030
# 2001     6922
# 2002     7797
# 2003     3865
# 2004     7559
# 2005    19239
# 2006    21805
# 2007    24651
# 2008    26469
# 2009    26093
# 2010    26397
# 2011    29345
# 2012    31057
# 2013    32758
# 2014    30751
# 2015    35197
# 2016    35660
# 2017    37097
# 2018    39271
# 2019    40265
# 2020    46102
# 2021    46745
# 2022    35921
# 2023       13
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)

# %%
cntrbtrs = pd.read_csv('/content/drive/MyDrive/Hack_Sochi/train/cntrbtrs.csv', sep=';')

# %%
cntrbtrs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911470 entries, 0 to 911469
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   slctn_nmbr       911470 non-null  int64
#  1   npo_accnt_id     911470 non-null  object
#  2   accnt_pnsn_schm  911172 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 20.9+ MB

# %%
cntrbtrs.head()
# Out:
#    slctn_nmbr                        npo_accnt_id  accnt_pnsn_schm
# 0           2  0x66FC8B311E1E204187F41966B73E313F              0.0
# 1           2  0x675F74AFB447EF40AF1E4C042CCA440C              0.0
# 2           2  0x6FFA52921209184BA47B1E919B713894              0.0
# 3           2  0xB51B4374207FE0458B29FD1F9CBF69EB              1.0
# 4           2  0x7AC3935CC4DADE419F8378B9C276DEF7              2.0

# %%
cntrbtrs['slctn_nmbr'].value_counts(dropna=False)
# Out:
# slctn_nmbr
# 0    432587
# 3    193013
# 1    160722
# 2    125148
# Name: count, dtype: int64

# %%
cntrbtrs['accnt_pnsn_schm'].value_counts(dropna=False)
# Out:
# accnt_pnsn_schm
# 350.0    112539
# 351.0     98513
# 354.0     58687
# 352.0     42615
# 0.0       36751
#           ...
# 273.0         1
# 277.0         1
# 281.0         1
# 291.0         1
# 537.0         1
# Name: count, Length: 539, dtype: int64

# %% [markdown]
# Всего 4 номера выборки и 538 схем пенс счетов и есть пустой

# %%
cntrbtrs['accnt_pnsn_schm'].value_counts(dropna=False).head(10)
# Out:
# accnt_pnsn_schm
# 350.0    112539
# 351.0     98513
# 354.0     58687
# 352.0     42615
# 0.0       36751
# 430.0     23479
# 428.0     20597
# 426.0     18164
# 427.0     17975
# 366.0     17909
# Name: count, dtype: int64

# %%
cntrbtrs[cntrbtrs['accnt_pnsn_schm'].isna()]
# Out:
#         slctn_nmbr                        npo_accnt_id  accnt_pnsn_schm
# 48137            2  0x80D2005056AB16F911E6B94244A21118              NaN
# 98139            2  0x80D2005056AB16F911E6B9427B09F913              NaN
# 101968           2  0x80D2005056AB16F911E6B94CD47B13FA              NaN
# 105385           2  0x50F03AE3BFCC3E429C71EAD8F872EE0C              NaN
# 106835           2  0x80D2005056AB16F911E6B94D433AC86D              NaN
# ...            ...                                 ...              ...
# 284667           1  0x521B2264D5D1A34C8237B62B6BCD73C1              NaN
# 285010           1  0x172D33AE68EA8541B3AF1A2CEEBCC2BD              NaN
# 285034           1  0x97C4B5F299C4DA4CBB2CDC67BCCDEB82              NaN
# 285086           1  0x8C3459F0572FB04AA874473FC85E53BC              NaN
# 845823           3  0x9EC49F255267D87541EF821895789A73              NaN
#
# [298 rows x 3 columns]

# %% [markdown]
# 298 счетов с пустой схемой. Может быть, из 90-х годов ?

# %%
cntrbtrs[cntrbtrs['accnt_pnsn_schm'].isna()]['slctn_nmbr'].value_counts(dropna=False)
# Out:
# slctn_nmbr
# 1    292
# 2      5
# 3      1
# Name: count, dtype: int64

# %% [markdown]
# Почти все счета с пустой схемой имеют номер выборки 1, при этом выборка 1 только на 3 месте в общем случае. Надо посмотреть отделбно что это за выборка

# %% [markdown]
# ### train.csv

# %%
train = pd.read_csv('/content/drive/MyDrive/Hack_Sochi/train/train.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3589918 entries, 0 to 3589917
# Data columns (total 42 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   slctn_nmbr              int64
#  1   client_id               object
#  2   npo_account_id          object
#  3   npo_accnts_nmbr         int64
#  4   pmnts_type              int64
#  5   year                    int64
#  6   quarter                 object
#  7   gender                  int64
#  8   age                     int64
#  9   clnt_cprtn_time_d       int64
#  10  actv_prd_d              int64
#  11  lst_pmnt_rcnc_d         int64
#  12  balance                 float64
#  13  oprtn_sum_per_qrtr      float64
#  14  oprtn_sum_per_year      float64
#  15  frst_pmnt_date          object
#  16  lst_pmnt_date_per_qrtr  object
#  17  frst_pmnt               float64
#  18  lst_pmnt                float64
#  19  pmnts_sum               float64
#  20  pmnts_nmbr              int64
# ...

# %%
train.head()
# Out:
#    slctn_nmbr                           client_id  \
# 0           1  0xA095932790098744A2325A8D152C05C7
# 1           0  0xF75BAA20A603A2479005DEB80464336E
# 2           2  0x0D18081E0556AF4F95A931FBA4159D52
# 3           0  0x0AD72BC5475D9A4D83E12350A84F839D
# 4           0  0x73DF06339CC25840838408BAD52BE223
#
#                        npo_account_id  npo_accnts_nmbr  pmnts_type  year  \
# 0  0xD4DBBAC6561929409BA45725A220613E                1           2  2017
# 1  0x3DCFF11974B3D8458CE3569DE9E855D5                2           2  2009
# 2  0x9DADF88CB3407C4E89403315F640393E                1           1  2010
# 3  0xF59C4E62F115684899EAE9B5D5ECF70F                1           1  2005
# 4  0x35BFFA05321C014B9FC29A189E89EDF0                2           2  2007
#
#   quarter  gender  age  clnt_cprtn_time_d  actv_prd_d  lst_pmnt_rcnc_d  \
# 0  2017Q4       1   48               8091           0             6757
# 1  2009Q1       1   35               3303        1531               34
# ...

# %% [markdown]
# Видимо, у нас данные за полный квартал, поэтому признаки именно в этом квартале типа больших выплат должны указывать на отток.

# %% [markdown]
# Отток по годам

# %%
train['year'].value_counts().sort_index()
# Out:
# year
# 1993      3021
# 1994      9627
# 1995      2011
# 1996     10224
# 1997     15059
# 1998     11403
# 1999     37134
# 2000     39793
# 2001     39967
# 2002     44293
# 2003     21609
# 2004     42214
# 2005    108571
# 2006    122423
# 2007    139980
# 2008    149197
# 2009    147355
# 2010    147348
# 2011    168515
# 2012    174366
# 2013    185614
# 2014    174107
# 2015    200222
# 2016    202495
# 2017    210583
# 2018    222391
# 2019    230436
# 2020    261861
# 2021    262879
# 2022    205119
# 2023       101
# Name: count, dtype: int64

# %% [markdown]
# 23 год только 101 запись, в 22 году число записей

# %%
train.groupby(['year'])['churn'].sum()
# Out:
# year
# 1993       0
# 1994       0
# 1995       0
# 1996       0
# 1997       0
# 1998       0
# 1999       0
# 2000       0
# 2001       0
# 2002       0
# 2003      19
# 2004     962
# 2005    3388
# 2006    2094
# 2007    2473
# 2008    3612
# 2009    2665
# 2010    2389
# 2011    2167
# 2012    2382
# 2013    3985
# 2014    3043
# 2015    3146
# 2016    3863
# 2017    4312
# 2018    3513
# 2019    1885
# 2020    4022
# 2021    4086
# 2022    2082
# 2023       0
# Name: churn, dtype: int64

# %%
train.groupby(['year'])['churn'].mean()
# Out:
# year
# 1993    0.000000
# 1994    0.000000
# 1995    0.000000
# 1996    0.000000
# 1997    0.000000
# 1998    0.000000
# 1999    0.000000
# 2000    0.000000
# 2001    0.000000
# 2002    0.000000
# 2003    0.000879
# 2004    0.022789
# 2005    0.031205
# 2006    0.017105
# 2007    0.017667
# 2008    0.024210
# 2009    0.018086
# 2010    0.016213
# 2011    0.012859
# 2012    0.013661
# 2013    0.021469
# 2014    0.017478
# 2015    0.015713
# 2016    0.019077
# 2017    0.020476
# 2018    0.015797
# 2019    0.008180
# 2020    0.015359
# 2021    0.015543
# 2022    0.010150
# 2023    0.000000
# Name: churn, dtype: float64

# %%
19/21609, 962/42214
# Out:
# (0.0008792632699338239, 0.022788648315724643)

# %%
train.head()
# Out:
#    slctn_nmbr                           client_id  \
# 0           1  0xA095932790098744A2325A8D152C05C7
# 1           0  0xF75BAA20A603A2479005DEB80464336E
# 2           2  0x0D18081E0556AF4F95A931FBA4159D52
# 3           0  0x0AD72BC5475D9A4D83E12350A84F839D
# 4           0  0x73DF06339CC25840838408BAD52BE223
#
#                        npo_account_id  npo_accnts_nmbr  pmnts_type  year  \
# 0  0xD4DBBAC6561929409BA45725A220613E                1           2  2017
# 1  0x3DCFF11974B3D8458CE3569DE9E855D5                2           2  2009
# 2  0x9DADF88CB3407C4E89403315F640393E                1           1  2010
# 3  0xF59C4E62F115684899EAE9B5D5ECF70F                1           1  2005
# 4  0x35BFFA05321C014B9FC29A189E89EDF0                2           2  2007
#
#   quarter  gender  age  clnt_cprtn_time_d  actv_prd_d  lst_pmnt_rcnc_d  \
# 0  2017Q4       1   48               8091           0             6757
# 1  2009Q1       1   35               3303        1531               34
# ...

# %%
train['region'].value_counts().tail(25)

# %%
train['region'].value_counts().head(100)

# %%
train.info()

# %%
train[train['year']>=2004]['region'].value_counts().head(120)

# %%
train.head()
# Out:
#    slctn_nmbr                           client_id  \
# 0           1  0xA095932790098744A2325A8D152C05C7
# 1           0  0xF75BAA20A603A2479005DEB80464336E
# 2           2  0x0D18081E0556AF4F95A931FBA4159D52
# 3           0  0x0AD72BC5475D9A4D83E12350A84F839D
# 4           0  0x73DF06339CC25840838408BAD52BE223
#
#                        npo_account_id  npo_accnts_nmbr  pmnts_type  year  \
# 0  0xD4DBBAC6561929409BA45725A220613E                1           2  2017
# 1  0x3DCFF11974B3D8458CE3569DE9E855D5                2           2  2009
# 2  0x9DADF88CB3407C4E89403315F640393E                1           1  2010
# 3  0xF59C4E62F115684899EAE9B5D5ECF70F                1           1  2005
# 4  0x35BFFA05321C014B9FC29A189E89EDF0                2           2  2007
#
#   quarter  gender  age  clnt_cprtn_time_d  actv_prd_d  lst_pmnt_rcnc_d  \
# 0  2017Q4       1   48               8091           0             6757
# 1  2009Q1       1   35               3303        1531               34
# ...

# %% [markdown]
# ### Таблица клиентов, склонных к оттоку
# квартал забыл, поэтому были дубли клиентов

# %%
train[train['year']==2022]['client_id'].count(), train[train['year']==2022]['client_id'].nunique()
# Out:
# (205119, 65201)

# %%
train[train['year']==2022]['npo_accnts_nmbr'].value_counts()
# Out:
# npo_accnts_nmbr
# 1    126655
# 2     66057
# 3      9513
# 4      2142
# 5       600
# 6       126
# 7        16
# 8        10
# Name: count, dtype: int64

# %% [markdown]
# не понимаю, почему уник клиентов не 126655

# %%
train[(train['year']==2022)&(train['npo_accnts_nmbr']==2)].head()
# Out:
#      slctn_nmbr                           client_id  \
# 47            0  0xD21813BABB3C5A408485F361B9151CA6
# 105           0  0xA62B005056964A2C11EDADE5A9266610
# 141           0  0xAB781A088B71F54AA17405F27DF15111
# 142           0  0x3EC24DB6A5F97B4B97E19AF1F5728E5A
# 156           2  0xDA325E48F9C8AF4294C78682FFC58E36
#
#                          npo_account_id  npo_accnts_nmbr  pmnts_type  year  \
# 47   0x8A8E2A8FAEB95E45A3BC64DE56C1A429                2           3  2022
# 105  0xA62B005056964A2C11EDAEA5ABE1DCC0                2           1  2022
# 141  0xB18F74435EEB4C41ADDA0E73FF52E3BC                2           1  2022
# 142  0xA762B17E673CC04092E1F947197F3233                2           3  2022
# 156  0xD9B16CDA9122CD4D95297B1405B0217D                2           1  2022
#
#     quarter  gender  age  clnt_cprtn_time_d  actv_prd_d  lst_pmnt_rcnc_d  \
# 47   2022Q4       1   45               1095        1006               31
# ...

# %%
train[(train['year']==2022)&(train['client_id']=='0xD21813BABB3C5A408485F361B9151CA6')].sort_values('quarter', ascending=False)
# Out:
#          slctn_nmbr                           client_id  \
# 47                0  0xD21813BABB3C5A408485F361B9151CA6
# 1097801           0  0xD21813BABB3C5A408485F361B9151CA6
# 803743            0  0xD21813BABB3C5A408485F361B9151CA6
#
#                              npo_account_id  npo_accnts_nmbr  pmnts_type  \
# 47       0x8A8E2A8FAEB95E45A3BC64DE56C1A429                2           3
# 1097801  0x8A8E2A8FAEB95E45A3BC64DE56C1A429                2           3
# 803743   0x8A8E2A8FAEB95E45A3BC64DE56C1A429                2           3
#
#          year quarter  gender  age  clnt_cprtn_time_d  actv_prd_d  \
# 47       2022  2022Q4       1   45               1095        1006
# 1097801  2022  2022Q3       1   45               1003         914
# 803743   2022  2022Q1       1   45                820         733
#
#          lst_pmnt_rcnc_d    balance  oprtn_sum_per_qrtr  oprtn_sum_per_year  \
# 47                    31  284003.20            22230.99            102380.2
# ...

# %% [markdown]
# Почему нет 2 квартала, а 1 и 3,4 есть?

# %%
train[(train['client_id']=='0xD21813BABB3C5A408485F361B9151CA6')].sort_values('quarter', ascending=False)

# %%
train[(train['npo_account_id']=='0x8A8E2A8FAEB95E45A3BC64DE56C1A429')].sort_values('quarter', ascending=False).head(10)

# %% [markdown]
# ### Ладно, это потом, сначала сделать табличку для Эмиля

# %%
train[(train['year']==2022)&(train['quarter']=='2022Q4')].head()
# Out:
#      slctn_nmbr                           client_id  \
# 47            0  0xD21813BABB3C5A408485F361B9151CA6
# 68            0  0x84FBB407B7082540A2885A2A99D60432
# 328           0  0xC5BB7B0D926F6F4387CE8362CC763DC0
# 547           0  0xA634005056964A2C11EE4E2718ACBDC8
# 832           0  0xB9C2A95250AE0846A0AAA02B8EC5D717
#
#                          npo_account_id  npo_accnts_nmbr  pmnts_type  year  \
# 47   0x8A8E2A8FAEB95E45A3BC64DE56C1A429                2           3  2022
# 68   0x8C965E174E3E0E4E8C391A0C2E859134                1           3  2022
# 328  0xBB42F38143105E4C996968D29BE1008E                2           1  2022
# 547  0xA634005056964A2C11EE69ADCBD5BE77                1           3  2022
# 832  0x44CA6910C3C5904BA87936C53926BABC                1           3  2022
#
#     quarter  gender  age  clnt_cprtn_time_d  actv_prd_d  lst_pmnt_rcnc_d  \
# 47   2022Q4       1   45               1095        1006               31
# ...

# %%
train[(train['year']==2022)&(train['quarter']=='2022Q4')]['client_id'].count(), train[(train['year']==2022)&(train['quarter']=='2022Q4')]['client_id'].nunique()
# Out:
# (53121, 52324)

# %%
train[(train['year']==2022)&(train['quarter']=='2022Q4')]['npo_accnts_nmbr'].value_counts()
# Out:
# npo_accnts_nmbr
# 1    32803
# 2    16820
# 3     2565
# 4      723
# 5      166
# 6       36
# 7        5
# 8        3
# Name: count, dtype: int64

# %%
32803+16820*2+2565*33+723*4+166*5+36*6
# Out:
# 155026

# %% [markdown]
# Вывод: не все договоры показаны, видимо

# %%
columns_2front = ['client_id', 'npo_account_id', 'gender', 'age', 'region', 'npo_accnts_nmbr', 'pmnts_type','balance','lst_pmnt_date_per_qrtr',
                  'phone_number','email','lk']

# %%
train.columns

# %%
tr_fron1 = train[(train['year']==2022)&(train['quarter']=='2022Q4')][columns_2front]

# %%
tr_fron1.head()
# Out:
#                               client_id                      npo_account_id  \
# 47   0xD21813BABB3C5A408485F361B9151CA6  0x8A8E2A8FAEB95E45A3BC64DE56C1A429
# 68   0x84FBB407B7082540A2885A2A99D60432  0x8C965E174E3E0E4E8C391A0C2E859134
# 328  0xC5BB7B0D926F6F4387CE8362CC763DC0  0xBB42F38143105E4C996968D29BE1008E
# 547  0xA634005056964A2C11EE4E2718ACBDC8  0xA634005056964A2C11EE69ADCBD5BE77
# 832  0xB9C2A95250AE0846A0AAA02B8EC5D717  0x44CA6910C3C5904BA87936C53926BABC
#
#     gender  age                                       region  npo_accnts_nmbr  \
# 47       М   45  ХАНТЫ-МАНСИЙСКИЙ АВТОНОМНЫЙ ОКРУГ - ЮГРА АО                2
# 68       М   53                                САМАРСКАЯ ОБЛ                1
# 328      М   39                              УДМУРТСКАЯ РЕСП                2
# 547      Ж   46                            ЯМАЛО-НЕНЕЦКИЙ АО                1
# 832      М   54                                ПЕРМСКИЙ КРАЙ                1
#
# ...

# %%
tr_fron1['gender'] = tr_fron1['gender'].map({-1:'Ж', 1:'М'})

# %%
tr_fron1['phone_number'] = tr_fron1['phone_number'].map({1:'Да', -1:'Нет', 0:'Нет данных'})

# %%
tr_fron1['email'] = tr_fron1['email'].map({1:'Да', -1:'Нет', 0:'Нет данных'})

# %%
tr_fron1['lk'] = tr_fron1['lk'].map({1:'Да', -1:'Нет', 0:'Нет данных'})

# %%
tr_fron1['pmnts_type'] = tr_fron1['pmnts_type'].map({0:'не определен', 1:'смешанные', 2:'через банк', 3:'от работодателя'})

# %%
tr_fron1['churn_prop'] = 1

# %%
tr_fron1['churn_prop'] = tr_fron1['churn_prop'].apply(lambda x: round(np.random.uniform(0, 1),4))

# %%
#tr_fron1['perc_rank_churn'] = df.Pay.rank(pct = True)

# %%
tr_fron1.columns
# Out:
# Index(['client_id', 'npo_account_id', 'gender', 'age', 'region',
#        'npo_accnts_nmbr', 'pmnts_type', 'balance', 'lst_pmnt_date_per_qrtr',
#        'phone_number', 'email', 'lk', 'churn_prop'],
#       dtype='object')

# %%
tr_fron1[['client_id', 'npo_account_id','churn_prop', 'gender', 'age', 'region',
       'npo_accnts_nmbr', 'pmnts_type', 'balance', 'lst_pmnt_date_per_qrtr',
       'phone_number', 'email', 'lk']].head()
# Out:
#                               client_id                      npo_account_id  \
# 47   0xD21813BABB3C5A408485F361B9151CA6  0x8A8E2A8FAEB95E45A3BC64DE56C1A429
# 68   0x84FBB407B7082540A2885A2A99D60432  0x8C965E174E3E0E4E8C391A0C2E859134
# 328  0xC5BB7B0D926F6F4387CE8362CC763DC0  0xBB42F38143105E4C996968D29BE1008E
# 547  0xA634005056964A2C11EE4E2718ACBDC8  0xA634005056964A2C11EE69ADCBD5BE77
# 832  0xB9C2A95250AE0846A0AAA02B8EC5D717  0x44CA6910C3C5904BA87936C53926BABC
#
#      churn_prop gender  age                                       region  \
# 47       0.8149      М   45  ХАНТЫ-МАНСИЙСКИЙ АВТОНОМНЫЙ ОКРУГ - ЮГРА АО
# 68       0.2625      М   53                                САМАРСКАЯ ОБЛ
# 328      0.3557      М   39                              УДМУРТСКАЯ РЕСП
# 547      0.3990      Ж   46                            ЯМАЛО-НЕНЕЦКИЙ АО
# 832      0.9250      М   54                                ПЕРМСКИЙ КРАЙ
#
# ...

# %% [markdown]
# ### Сохраняю

# %%
tr_fron1[['client_id', 'npo_account_id','churn_prop', 'gender', 'age', 'region',
       'npo_accnts_nmbr', 'pmnts_type', 'balance', 'lst_pmnt_date_per_qrtr',
       'phone_number', 'email', 'lk']].to_csv('/content/drive/MyDrive/Hack_Sochi/acc_churn_t1.csv', index = False)

# %%
acc1 = pd.read_csv('/content/drive/MyDrive/Hack_Sochi/acc_churn_t1.csv')

# %%
acc1['lk'].value_counts()
# Out:
# lk
# Да     27247
# Нет    25874
# Name: count, dtype: int64

# %%
acc1['phone_number'].value_counts()
# Out:
# phone_number
# Нет           48923
# Нет данных     4050
# Да              148
# Name: count, dtype: int64

# %%
acc1['email'].value_counts()
# Out:
# email
# Нет данных    48640
# Нет            4465
# Да               16
# Name: count, dtype: int64

# %% [markdown]
# Таблица транзакций

# %%
transact = pd.read_csv('/content/drive/MyDrive/Hack_Sochi/train/trnsctns.csv', sep=';')

# %%
transact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26337901 entries, 0 to 26337900
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   slctn_nmbr      int64
#  1   npo_account_id  object
#  2   npo_sum         float64
#  3   npo_oprtn_date  object
#  4   npo_oprtn_grp   int64
#  5   quarter         object
#  6   year            int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.4+ GB

# %%
transact.head()
# Out:
#    slctn_nmbr                      npo_account_id  npo_sum npo_oprtn_date  \
# 0           2  0x555990CC98CCF8469BE5911D37811A4A    57.72     2000-01-02
# 1           2  0x555990CC98CCF8469BE5911D37811A4A   288.61     2000-01-03
# 2           2  0x555990CC98CCF8469BE5911D37811A4A    78.04     2000-01-16
# 3           2  0x555990CC98CCF8469BE5911D37811A4A    78.04     2000-02-15
# 4           2  0x555990CC98CCF8469BE5911D37811A4A    85.36     2000-03-16
#
#    npo_oprtn_grp quarter  year
# 0              0  2000Q1  2000
# 1              0  2000Q1  2000
# 2              1  2000Q1  2000
# 3              1  2000Q1  2000
# 4              1  2000Q1  2000

# %%
transact.groupby('slctn_nmbr').agg({'quarter':['min', 'max']})
# Out:
#            quarter
#                min     max
# slctn_nmbr
# 0           1999Q4  2023Q1
# 1           1993Q2  2023Q1
# 2           2000Q1  2023Q1
# 3           2003Q3  2023Q1

# %%
transact['year'].value_counts().sort_index()
# Out:
# year
# 1993      17294
# 1994      55367
# 1995      15922
# 1996      62025
# 1997      66161
# 1998      51707
# 1999      93904
# 2000      95199
# 2001     111330
# 2002     102087
# 2003      50516
# 2004     317296
# 2005     648101
# 2006    1041523
# 2007    1015132
# 2008    1759620
# 2009    1445688
# 2010    1468312
# 2011    1182721
# 2012    2087359
# 2013    1741909
# 2014    1490955
# 2015     926927
# 2016    2042050
# 2017    1399632
# 2018    1656100
# 2019     935440
# 2020    2009646
# 2021    1429794
# 2022     936185
# 2023      81999
# Name: count, dtype: int64

# %%
transact_2 = transact[transact['year'].between(2019, 2022)]

# %%
train.head()

# %%
train.groupby('slctn_nmbr').agg({'quarter':['min', 'max']})
# Out:
#            quarter
#                min     max
# slctn_nmbr
# 0           2003Q4  2023Q1
# 1           1993Q2  2023Q1
# 2           2001Q3  2023Q1
# 3           2005Q4  2023Q1

# %%
train[(train['churn']==1)&(train['quarter'].between('2019','2022Q4'))].head()
# Out:
#      slctn_nmbr                           client_id  \
# 38            0  0x04F305A6C59E984FAB50F1CCF18E0496
# 125           0  0x2973C561A47AB04097020E2F92A73730
# 211           0  0xC423AAF753329942930C200D46A60F63
# 219           0  0xFE8CBBCA10FA554F985122B1B9DE18CC
# 470           2  0xA385D2406E8E2F4092A05471D41552B9
#
#                          npo_account_id  npo_accnts_nmbr  pmnts_type  year  \
# 38   0x17AA4D9556DBC64DA3D6BD7F1C1B9F0C                1           1  2020
# 125  0x99F0F6D8D97839478D35FD901D38ECBB                1           1  2021
# 211  0xADBBCA8A39660049B9AA58143FE121FC                2           3  2021
# 219  0x411584FCF08931438FB171F4C26CC936                2           3  2021
# 470  0x5A4A8C2247731F449A8686590B40019A                1           1  2021
#
#     quarter  gender  age  clnt_cprtn_time_d  actv_prd_d  lst_pmnt_rcnc_d  \
# 38   2020Q4       1   43               2733        2465              268
# ...

# %%
tr1922 = train[(train['churn']==1)&(train['quarter'].between('2019','2022Q4'))][]

# %%
train.columns
# Out:
# Index(['slctn_nmbr', 'client_id', 'npo_account_id', 'npo_accnts_nmbr',
#        'pmnts_type', 'year', 'quarter', 'gender', 'age', 'clnt_cprtn_time_d',
#        'actv_prd_d', 'lst_pmnt_rcnc_d', 'balance', 'oprtn_sum_per_qrtr',
#        'oprtn_sum_per_year', 'frst_pmnt_date', 'lst_pmnt_date_per_qrtr',
#        'frst_pmnt', 'lst_pmnt', 'pmnts_sum', 'pmnts_nmbr',
#        'pmnts_sum_per_qrtr', 'pmnts_sum_per_year', 'pmnts_nmbr_per_qrtr',
#        'pmnts_nmbr_per_year', 'incm_sum', 'incm_per_qrtr', 'incm_per_year',
#        'mgd_accum_period', 'mgd_payment_period', 'phone_number', 'email', 'lk',
#        'assignee_npo', 'assignee_ops', 'postal_code', 'region', 'citizen',
#        'fact_addrss', 'appl_mrkr', 'evry_qrtr_pmnt', 'churn'],
#       dtype='object')

# %% [markdown]
# ### Я хочу сделать поквартально сумму потерь по ушедшим договорам
# Но вопрос - если брать balance, не будет ли там 0, если клиент ушел?

# %%
train[(train['churn']==1)&(train['quarter'].between('2019','2022Q4'))].head()
# Out:
#      slctn_nmbr                           client_id  \
# 38            0  0x04F305A6C59E984FAB50F1CCF18E0496
# 125           0  0x2973C561A47AB04097020E2F92A73730
# 211           0  0xC423AAF753329942930C200D46A60F63
# 219           0  0xFE8CBBCA10FA554F985122B1B9DE18CC
# 470           2  0xA385D2406E8E2F4092A05471D41552B9
#
#                          npo_account_id  npo_accnts_nmbr  pmnts_type  year  \
# 38   0x17AA4D9556DBC64DA3D6BD7F1C1B9F0C                1           1  2020
# 125  0x99F0F6D8D97839478D35FD901D38ECBB                1           1  2021
# 211  0xADBBCA8A39660049B9AA58143FE121FC                2           3  2021
# 219  0x411584FCF08931438FB171F4C26CC936                2           3  2021
# 470  0x5A4A8C2247731F449A8686590B40019A                1           1  2021
#
#     quarter  gender  age  clnt_cprtn_time_d  actv_prd_d  lst_pmnt_rcnc_d  \
# 38   2020Q4       1   43               2733        2465              268
# ...

# %% [markdown]
# ### Колоссальный пример с дата ликом

# %%
train[(train['npo_account_id']=='0x17AA4D9556DBC64DA3D6BD7F1C1B9F0C')&(train['quarter'].between('2019','2022Q4'))].sort_values('quarter')
# Out:
#          slctn_nmbr                           client_id  \
# 1259753           0  0x04F305A6C59E984FAB50F1CCF18E0496
# 1153688           0  0x04F305A6C59E984FAB50F1CCF18E0496
# 2653077           0  0x04F305A6C59E984FAB50F1CCF18E0496
# 980312            0  0x04F305A6C59E984FAB50F1CCF18E0496
# 642738            0  0x04F305A6C59E984FAB50F1CCF18E0496
# 38                0  0x04F305A6C59E984FAB50F1CCF18E0496
#
#                              npo_account_id  npo_accnts_nmbr  pmnts_type  \
# 1259753  0x17AA4D9556DBC64DA3D6BD7F1C1B9F0C                1           1
# 1153688  0x17AA4D9556DBC64DA3D6BD7F1C1B9F0C                1           1
# 2653077  0x17AA4D9556DBC64DA3D6BD7F1C1B9F0C                1           1
# 980312   0x17AA4D9556DBC64DA3D6BD7F1C1B9F0C                1           1
# 642738   0x17AA4D9556DBC64DA3D6BD7F1C1B9F0C                1           1
# 38       0x17AA4D9556DBC64DA3D6BD7F1C1B9F0C                1           1
#
# ...

# %%
train[(train['npo_account_id']=='0x99F0F6D8D97839478D35FD901D38ECBB')&(train['quarter'].between('2019','2022Q4'))].sort_values('quarter')
# Out:
#          slctn_nmbr                           client_id  \
# 1092163           0  0x2973C561A47AB04097020E2F92A73730
# 377625            0  0x2973C561A47AB04097020E2F92A73730
# 2942659           0  0x2973C561A47AB04097020E2F92A73730
# 2964705           0  0x2973C561A47AB04097020E2F92A73730
# 3424539           0  0x2973C561A47AB04097020E2F92A73730
# 1076465           0  0x2973C561A47AB04097020E2F92A73730
# 2845367           0  0x2973C561A47AB04097020E2F92A73730
# 3563643           0  0x2973C561A47AB04097020E2F92A73730
# 22147             0  0x2973C561A47AB04097020E2F92A73730
# 125               0  0x2973C561A47AB04097020E2F92A73730
#
#                              npo_account_id  npo_accnts_nmbr  pmnts_type  \
# 1092163  0x99F0F6D8D97839478D35FD901D38ECBB                1           1
# 377625   0x99F0F6D8D97839478D35FD901D38ECBB                1           1
# 2942659  0x99F0F6D8D97839478D35FD901D38ECBB                1           1
# ...

# %% [markdown]
# ## Делаю таблицу для расчета суммы потерь по региону-кварталам
# Топ регионов беру и все

# %%
train[(train['churn']==1)&(train['quarter'].between('2018','2022Q4'))]['region'].value_counts()

# %% [markdown]
# Почему на 1 месте по оттоку Вологодская обл и Югра?
# Вологодская, Башкортостан, Липецкая, Югра - больше всего записей

# %%
a = train[(train['quarter'].between('2018','2022Q4'))& (~train['region'].isin(['БЕЛАРУСЬ','КАЗАХСТАН','УКРАИНА','ОБЪЕДИНЕННЫЕ АРАБСКИЕ ЭМИРАТЫ']))]

# %%
a['region'] = a['region'].replace(['БАШКОРТОСТАН РЕСП.',  'БАШКОРТОСТАН',  'БАШКОРТОСТАН РЕСП',  'РЕСП БАШКОРТОСТАН','БЕЛЕБЕЕВСКИЙ','БЕЛЕБЕЕВСКИЙ Р-Н'
  ,'ДЮРТЮЛИНСКИЙ','ДЮРТЮЛИНСКИЙ Р-Н','ИШИМБАЙСКИЙ','КРАСНОКАМСКИЙ','ТУЙМАЗИНСКИЙ','ТУЙМАЗИНСКИЙ Р-Н','УФИМСКИЙ','ЯНАУЛЬСКИЙ','БИРСКИЙ'
  ,'ЯНАУЛЬСКИЙ Р-Н','ЧИШМИНСКИЙ','ТАТЫШЛИНСКИЙ','УФИМСКИЙ Р-Н','УЧАЛИНСКИЙ','БАЙМАКСКИЙ','БАКАЛИНСКИЙ','ГАФУРИЙСКИЙ','ДАВЛЕКАНОВСКИЙ'
  ,'ЕРМЕКЕЕВСКИЙ','ИГЛИНСКИЙ','ИШИМБАЙСКИЙ Р-Н','КАЛТАСИНСКИЙ','КРАСНОКАМСКИЙ Р-Н','КУШНАРЕНКОВСКИЙ','ШАРАНСКИЙ','МЕЛЕУЗОВСКИЙ','КУГАРЧИНСКИЙ'
  ,'КАРАИДЕЛЬСКИЙ','КАЛТАСИНСКИЙ Р-Н','БЛАГОВЕЩЕНСКИЙ','НУРИМАНОВСКИЙ','ЗИАНЧУРИНСКИЙ'], 'БАШКОРТОСТАН РЕСП.')
# Out:
# <ipython-input-94-33111bf3221c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['region'] = a['region'].replace(['БАШКОРТОСТАН РЕСП.',  'БАШКОРТОСТАН',  'БАШКОРТОСТАН РЕСП',  'РЕСП БАШКОРТОСТАН','БЕЛЕБЕЕВСКИЙ','БЕЛЕБЕЕВСКИЙ Р-Н'

# %%
a['region'] = a['region'].replace(['ХАНТЫ-МАНСИЙСКИЙ АВТОНОМНЫЙ ОКРУГ - ЮГРА','ХАНТЫ-МАНСИЙСКИЙ АВТОНОМНЫЙ ОКРУГ - ЮГРА АО','ХАНТЫ-МАНСИЙСКИЙ АВТОНОМНЫЙ ОКРУГ - ЮГРА АО.',
                                   'ХАНТЫ-МАНСИЙСКИЙ АО','ХАНТЫ-МАНСИЙСКИЙ-ЮГРА АО','НЕФТЕЮГАНСКИЙ Р-Н'], 'ХАНТЫ-МАНСИЙСКИЙ АО - ЮГРА')
a['region'] = a['region'].replace(['ИРКУТСКАЯ','ИРКУТСКАЯ ОБЛ'], 'ИРКУТСКАЯ ОБЛ')
a['region'] = a['region'].replace(['КЕМЕРОВСКАЯ ОБЛ','КЕМЕРОВСКАЯ ОБЛАСТЬ - КУЗБАСС','КЕМЕРОВСКАЯ ОБЛАСТЬ - КУЗБАСС ОБЛ'], 'КЕМЕРОВСКАЯ ОБЛ')
a['region'] = a['region'].replace(['КРАСНОДАРСКИЙ','КРАСНОДАРСКИЙ КРАЙ','КРАСНОДАРСКИЙ КРАЙ.'], 'КРАСНОДАРСКИЙ КРАЙ')
a['region'] = a['region'].replace(['КРАСНОЯРСКИЙ КРАЙ','КРАСНОЯРСКИЙ','КРАСНОЯРСКИЙ КРАЙ.'], 'КРАСНОЯРСКИЙ КРАЙ')
a['region'] = a['region'].replace(['ОРЕНБУРГСКАЯ','ОРЕНБУРГСКАЯ ОБЛ'], 'ОРЕНБУРГСКАЯ ОБЛ')
a['region'] = a['region'].replace(['САМАРСКАЯ','САМАРСКАЯ ОБЛ','САМАРСКАЯ ОБЛ.'], 'САМАРСКАЯ ОБЛ')
a['region'] = a['region'].replace(['ЯМАЛО-НЕНЕЦКИЙ','ЯМАЛО-НЕНЕЦКИЙ АО','ЯМАЛО-НЕНЕЦКИЙ АО.','ЯМАЛО-НЕНЕЦКИЙ АВТОНОМНЫЙ ОКРУГ'], 'ЯМАЛО-НЕНЕЦКИЙ АО')
a['region'] = a['region'].replace(['ЧЕЧЕНСКАЯ','ЧЕЧЕНСКАЯ РЕСП'], 'ЧЕЧЕНСКАЯ РЕСП')
a['region'] = a['region'].replace(['ХАБАРОВСКИЙ','ХАБАРОВСКИЙ КРАЙ'], 'ХАБАРОВСКИЙ КРАЙ')
a['region'] = a['region'].replace(['ТЮМЕНСКАЯ','ТЮМЕНСКАЯ ОБЛ'], 'ТЮМЕНСКАЯ ОБЛ')
a['region'] = a['region'].replace(['УДМУРТСКАЯ','УДМУРТСКАЯ РЕСП'], 'УДМУРТСКАЯ РЕСП')
a['region'] = a['region'].replace(['МОСКВА','МОСКВА Г','МОСКВА Г.'], 'МОСКВА')
a['region'] = a['region'].replace(['ЛИПЕЦКАЯ','ЛИПЕЦКАЯ ОБЛ','ЛИПЕЦКАЯ ОБЛ.'], 'ЛИПЕЦКАЯ ОБЛ')
a['region'] = a['region'].replace(['РЯЗАНСКАЯ','РЯЗАНСКАЯ ОБЛ','РЯЗАНСКАЯ ОБЛ.'], 'РЯЗАНСКАЯ ОБЛ')
a['region'] = a['region'].replace(['ТЮМЕНСКАЯ','ТЮМЕНСКАЯ ОБЛ','ТЮМЕНСКАЯ ОБЛ.'], 'ТЮМЕНСКАЯ ОБЛ')
a['region'] = a['region'].replace(['КОМИ','КОМИ РЕСП','КОМИ РЕСП.'], 'КОМИ РЕСП')
a['region'] = a['region'].replace(['ИРКУТСКАЯ','ИРКУТСКАЯ ОБЛ','ИРКУТСКАЯ ОБЛ.'], 'ИРКУТСКАЯ ОБЛ')
a['region'] = a['region'].replace(['ОХИНСКИЙ','САХАЛИНСКАЯ ОБЛ','САХАЛИНСКАЯ ОБЛ.'], 'САХАЛИНСКАЯ ОБЛ')
a['region'] = a['region'].replace(['СВЕРДЛОВСКАЯ','СВЕРДЛОВСКАЯ ОБЛ','СВЕРДЛОВСКАЯ ОБЛ.'], 'СВЕРДЛОВСКАЯ ОБЛ')
a['region'] = a['region'].replace(['ТАТАРСТАН','ТАТАРСТАН РЕСП','ТАТАРСТАН РЕСП.'], 'ТАТАРСТАН')
a['region'] = a['region'].replace(['САРАТОВСКАЯ','САРАТОВСКАЯ ОБЛ','САРАТОВСКАЯ ОБЛ.'], 'САРАТОВСКАЯ ОБЛ')
a['region'] = a['region'].replace(['ЧЕЛЯБИНСКАЯ','ЧЕЛЯБИНСКАЯ ОБЛ','ЧЕЛЯБИНСКАЯ ОБЛ.'], 'ЧЕЛЯБИНСКАЯ ОБЛ')
a['region'] = a['region'].replace(['ТОМСКАЯ','ТОМСКАЯ ОБЛ','ТОМСКАЯ ОБЛ.'], 'ТОМСКАЯ ОБЛ')

# %%
top_regions = a['region'].value_counts().head(85).index

# %%
top_regions
# Out:
# Index(['БАШКОРТОСТАН РЕСП.', 'ХАНТЫ-МАНСИЙСКИЙ АО - ЮГРА', 'ВОЛОГОДСКАЯ ОБЛ',
#        'ЛИПЕЦКАЯ ОБЛ', 'САМАРСКАЯ ОБЛ', 'ИРКУТСКАЯ ОБЛ', 'МОСКВА',
#        'УДМУРТСКАЯ РЕСП', 'СВЕРДЛОВСКАЯ ОБЛ', 'ОРЕНБУРГСКАЯ ОБЛ',
#        'КРАСНОДАРСКИЙ КРАЙ', 'КРАСНОЯРСКИЙ КРАЙ', 'ЯМАЛО-НЕНЕЦКИЙ АО',
#        'ЛЕНИНГРАДСКАЯ ОБЛ', 'МОСКОВСКАЯ ОБЛ', 'РЯЗАНСКАЯ ОБЛ',
#        'НИЖЕГОРОДСКАЯ ОБЛ', 'САРАТОВСКАЯ ОБЛ', 'ХАБАРОВСКИЙ КРАЙ',
#        'ТЮМЕНСКАЯ ОБЛ', 'САХАЛИНСКАЯ ОБЛ', 'АРХАНГЕЛЬСКАЯ ОБЛ', 'КОМИ РЕСП',
#        'САНКТ-ПЕТЕРБУРГ Г', 'ЧЕЛЯБИНСКАЯ ОБЛ', 'БЕЛГОРОДСКАЯ ОБЛ',
#        'СТАВРОПОЛЬСКИЙ КРАЙ', 'КУРСКАЯ ОБЛ', 'КАРЕЛИЯ РЕСП', 'ЧЕЧЕНСКАЯ РЕСП',
#        'ПЕРМСКИЙ КРАЙ', 'ТАТАРСТАН', 'ТОМСКАЯ ОБЛ', 'РОСТОВСКАЯ ОБЛ',
#        'ОРЛОВСКАЯ ОБЛ', 'ПСКОВСКАЯ ОБЛ', 'ОМСКАЯ ОБЛ', 'ДАГЕСТАН РЕСП',
#        'ПРИМОРСКИЙ КРАЙ', 'АЛТАЙСКИЙ КРАЙ', 'НОВОСИБИРСКАЯ ОБЛ',
#        'КУРГАНСКАЯ ОБЛ', 'УЛЬЯНОВСКАЯ ОБЛ', 'СМОЛЕНСКАЯ ОБЛ',
#        'ВОРОНЕЖСКАЯ ОБЛ', 'ЯРОСЛАВСКАЯ ОБЛ', 'КЕМЕРОВСКАЯ ОБЛ',
# ...

# %%
pd.DataFrame(top_regions).sort_values('region')
# Out:
#                             region
# 69                     АДЫГЕЯ РЕСП
# 82                      АЛТАЙ РЕСП
# 39                  АЛТАЙСКИЙ КРАЙ
# 49                    АМУРСКАЯ ОБЛ
# 21               АРХАНГЕЛЬСКАЯ ОБЛ
# 56                АСТРАХАНСКАЯ ОБЛ
# 0               БАШКОРТОСТАН РЕСП.
# 25                БЕЛГОРОДСКАЯ ОБЛ
# 48                    БРЯНСКАЯ ОБЛ
# 52                    БУРЯТИЯ РЕСП
# 57                ВЛАДИМИРСКАЯ ОБЛ
# 53               ВОЛГОГРАДСКАЯ ОБЛ
# 2                  ВОЛОГОДСКАЯ ОБЛ
# 44                 ВОРОНЕЖСКАЯ ОБЛ
# 37                   ДАГЕСТАН РЕСП
# 74                  ЕВРЕЙСКАЯ АОБЛ
# 71              ЗАБАЙКАЛЬСКИЙ КРАЙ
# 60                  ИВАНОВСКАЯ ОБЛ
# 79                  ИНГУШЕТИЯ РЕСП
# 5                    ИРКУТСКАЯ ОБЛ
# 78       КАБАРДИНО-БАЛКАРСКАЯ РЕСП
# 64             КАЛИНИНГРАДСКАЯ ОБЛ
# 72                   КАЛМЫКИЯ РЕСП
# 61                   КАЛУЖСКАЯ ОБЛ
# 77                 КАМЧАТСКИЙ КРАЙ
# 65       КАРАЧАЕВО-ЧЕРКЕССКАЯ РЕСП
# ...

# %%
a = train[(train['churn']==1)&(train['quarter'].between('2018','2022Q4')) & train['region'].isin(top_regions)]

# %%
loss_2save = a.groupby(['region','year','quarter'])[['balance','lst_pmnt']].sum().reset_index()

# %%
loss_2save
# Out:
#               region  year quarter     balance  lst_pmnt
# 0        АДЫГЕЯ РЕСП  2019  2019Q3  2085217.89  25104.95
# 1        АДЫГЕЯ РЕСП  2020  2020Q4   422441.72  14845.60
# 2        АДЫГЕЯ РЕСП  2021  2021Q1   190198.59   1910.57
# 3        АДЫГЕЯ РЕСП  2021  2021Q2   160695.83   6328.65
# 4        АДЫГЕЯ РЕСП  2021  2021Q3    30868.13   1382.83
# ..               ...   ...     ...         ...       ...
# 822  ЯРОСЛАВСКАЯ ОБЛ  2021  2021Q3   382593.95  23415.65
# 823  ЯРОСЛАВСКАЯ ОБЛ  2021  2021Q4   249336.44  19475.95
# 824  ЯРОСЛАВСКАЯ ОБЛ  2022  2022Q1   119774.52   2757.30
# 825  ЯРОСЛАВСКАЯ ОБЛ  2022  2022Q2   154812.69   3253.65
# 826  ЯРОСЛАВСКАЯ ОБЛ  2022  2022Q3   123308.50   8134.14
#
# [827 rows x 5 columns]

# %%
loss_2save.to_csv('/content/drive/MyDrive/Hack_Sochi/loss_region_qrt.csv')

# %% [markdown]
# ### Доля оттока

# %%
b = train[(train['quarter'].between('2018','2022Q4')) & train['region'].isin(top_regions)]

# %%
churn_2save = b.groupby(['region','year','quarter'])[['churn']].mean().reset_index()

# %%
churn_2save['qrtr_numb'] = churn_2save['quarter'].str[-1]

# %%
churn_2save
# Out:
#                region  year quarter     churn qrtr_numb
# 0         АДЫГЕЯ РЕСП  2018  2018Q1  0.000000         1
# 1         АДЫГЕЯ РЕСП  2018  2018Q2  0.000000         2
# 2         АДЫГЕЯ РЕСП  2018  2018Q3  0.000000         3
# 3         АДЫГЕЯ РЕСП  2018  2018Q4  0.000000         4
# 4         АДЫГЕЯ РЕСП  2019  2019Q1  0.000000         1
# ...               ...   ...     ...       ...       ...
# 1598  ЯРОСЛАВСКАЯ ОБЛ  2021  2021Q4  0.013228         4
# 1599  ЯРОСЛАВСКАЯ ОБЛ  2022  2022Q1  0.032787         1
# 1600  ЯРОСЛАВСКАЯ ОБЛ  2022  2022Q2  0.053571         2
# 1601  ЯРОСЛАВСКАЯ ОБЛ  2022  2022Q3  0.015152         3
# 1602  ЯРОСЛАВСКАЯ ОБЛ  2022  2022Q4  0.000000         4
#
# [1603 rows x 5 columns]

# %%
churn_2save.to_csv('/content/drive/MyDrive/Hack_Sochi/churn_region_qrt.csv', index=False)
